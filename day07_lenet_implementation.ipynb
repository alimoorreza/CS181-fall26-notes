# %% [markdown]
# <a href="https://colab.research.google.com/github/alimoorreza/CS181-fall26-notes/blob/main/day07_lenet_implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **CS181: Computer Vision, Fall 2026**
# ### LeNet: a popular convoluational neural network (CNN) implementation

# %% [markdown]
# ![MLP architecture](https://raw.githubusercontent.com/alimoorreza/CS181-fall26-notes/main/images/letnet_full.drawio.svg)

# %% [markdown]
# ## **Group Activity**: *Let’s try to mimic the CNN above by recreating a popular CNN called the **LeNet**. You should insert a $ReLU$ activation layer and a $max$-$pooling$ layer between each pair of adjacent Conv2D layers, as we did before, and connect the layers sequentially according to the specifications below:*

# %% [markdown]
# ## **Perform a forward pass of the input volume through your LeNet.**

# %%
# your code
# ...
# ...
# ...

# %%
import torch
from torch import nn

class MyLeNet(nn.Module):
    def __init__(self):
        super(MyLeNet, self).__init__()

        self.conv_layer1    = nn.Conv2d(1, 6, 5, 1, 0)
        self.relu_layer1    = nn.ReLU()
        self.avgpool_layer1 = nn.AvgPool2d(2, 2, 0)

        self.conv_layer2    = nn.Conv2d(6, 16, 5, 1, 0)
        self.relu_layer2    = nn.ReLU()
        self.avgpool_layer2 = nn.AvgPool2d(2, 2, 0)


        self.linear_layer1  = nn.Linear(16*5*5, 84)
        self.linear_layer2  = nn.Linear(84, 10)


    def forward(self, input):

        print(f"input shape: {input.shape}")

        output = self.conv_layer1(input)
        output = self.relu_layer1(output)
        print(f"output shape (conv2d layer1): {output.shape}")
        output = self.avgpool_layer1(output)
        print(f"output shape (avgpool layer1): {output.shape}")

        output = self.conv_layer2(output)
        output = self.relu_layer2(output)
        print(f"output shape (conv2d layer2): {output.shape}")
        output = self.avgpool_layer2(output)
        print(f"output shape (avgpool layer2): {output.shape}")

        # transform the volume into a long list of numbers by flatteing
        '''
        flatten = nn.Flatten()
        output  = flatten(output)
        # or the following way
        '''
        output = torch.flatten(output)
        print(f"output shape (after flatteing the pooling volume): {output.shape}")

        output = self.linear_layer1(output)
        print(f"output shape (linear layer1): {output.shape}")
        output = self.linear_layer2(output)
        print(f"output shape (linear layer2): {output.shape}")

        return output


my_lenet = MyLeNet()

input = torch.randn( (1, 1, 32, 32) )
output = my_lenet(input)
print(f"final output shape: {output.shape}")
# Out:
# input shape: torch.Size([1, 1, 32, 32])
# output shape (conv2d layer1): torch.Size([1, 6, 28, 28])
# output shape (avgpool layer1): torch.Size([1, 6, 14, 14])
# output shape (conv2d layer2): torch.Size([1, 16, 10, 10])
# output shape (avgpool layer2): torch.Size([1, 16, 5, 5])
# output shape (after flatteing the pooling volume): torch.Size([400])
# output shape (linear layer1): torch.Size([84])
# output shape (linear layer2): torch.Size([10])
# final output shape: torch.Size([10])
